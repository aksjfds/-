# %%
import matplotlib.pyplot as plt
import numpy as np
X = [225, 232, 232, 245, 235, 245, 270, 225, 240, 240,
     217, 195, 225, 185, 200, 220, 200, 210, 271, 240,
     220, 230, 215, 252, 225, 220, 206, 185, 227, 236]

plt.hist(X, bins=5, range=(179.5, 279.5),
         weights=np.zeros_like(X) + 1 / len(X))
# Out:
# (array([0.1       , 0.2       , 0.43333333, 0.2       , 0.06666667]),
#  array([179.5, 199.5, 219.5, 239.5, 259.5, 279.5]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(X)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf684de7d0>,
#   <matplotlib.lines.Line2D at 0x1cf684df290>],
#  'caps': [<matplotlib.lines.Line2D at 0x1cf684dfc10>,
#   <matplotlib.lines.Line2D at 0x1cf684e8510>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf684dded0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf684e89d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf684e9350>],
#  'means': []}
